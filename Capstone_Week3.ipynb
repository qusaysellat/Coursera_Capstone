# %% [markdown]
# <a href="https://colab.research.google.com/github/qusaysellat/Coursera_Capstone/blob/master/Capstone_Week3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Capstone Week3
# This notebook is the peer-reviewd assignment of the 3rd week of Coursera's capstone course - IBM data science certificate.

# %% [markdown]
# ### Important
# Folium maps will not display in Github. If you want to view them please go to [nbviewer](https://nbviewer.jupyter.org/github/qusaysellat/Coursera_Capstone/blob/master/Capstone_Week3.ipynb) and paste the link to Github notebook there
#  , or - a faster way - [view it instantly on nbviewer](https://nbviewer.jupyter.org/github/qusaysellat/Coursera_Capstone/blob/master/Capstone_Week3.ipynb).

# %% [markdown]
# # part 1

# %%
# import necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# read existing tables in the provided link
df = pd.read_html('https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M', header=0)

# %%
# take the first table as it contains the data we need
df=df[0]
df
# Out:
#     Postcode           Borough          Neighbourhood
# 0        M1A      Not assigned           Not assigned
# 1        M2A      Not assigned           Not assigned
# 2        M3A        North York              Parkwoods
# 3        M4A        North York       Victoria Village
# 4        M5A  Downtown Toronto           Harbourfront
# ..       ...               ...                    ...
# 282      M8Z         Etobicoke              Mimico NW
# 283      M8Z         Etobicoke     The Queensway West
# 284      M8Z         Etobicoke  Royal York South West
# 285      M8Z         Etobicoke         South of Bloor
# 286      M9Z      Not assigned           Not assigned
#
# [287 rows x 3 columns]

# %%
# determine the Not assigned Boroughs in order to ignore them
where_to_ignore = df['Borough']!='Not assigned'
where_to_ignore
# Out:
# 0      False
# 1      False
# 2       True
# 3       True
# 4       True
#        ...
# 282     True
# 283     True
# 284     True
# 285     True
# 286    False
# Name: Borough, Length: 287, dtype: bool

# %%
# ignore Not assigned Boroughs
df=df[where_to_ignore]
df
# Out:
#     Postcode           Borough             Neighbourhood
# 2        M3A        North York                 Parkwoods
# 3        M4A        North York          Victoria Village
# 4        M5A  Downtown Toronto              Harbourfront
# 5        M6A        North York          Lawrence Heights
# 6        M6A        North York            Lawrence Manor
# ..       ...               ...                       ...
# 281      M8Z         Etobicoke  Kingsway Park South West
# 282      M8Z         Etobicoke                 Mimico NW
# 283      M8Z         Etobicoke        The Queensway West
# 284      M8Z         Etobicoke     Royal York South West
# 285      M8Z         Etobicoke            South of Bloor
#
# [210 rows x 3 columns]

# %%
# reindex to reflect the change
df.reset_index(drop=True, inplace=True)
df
# Out:
#     Postcode           Borough             Neighbourhood
# 0        M3A        North York                 Parkwoods
# 1        M4A        North York          Victoria Village
# 2        M5A  Downtown Toronto              Harbourfront
# 3        M6A        North York          Lawrence Heights
# 4        M6A        North York            Lawrence Manor
# ..       ...               ...                       ...
# 205      M8Z         Etobicoke  Kingsway Park South West
# 206      M8Z         Etobicoke                 Mimico NW
# 207      M8Z         Etobicoke        The Queensway West
# 208      M8Z         Etobicoke     Royal York South West
# 209      M8Z         Etobicoke            South of Bloor
#
# [210 rows x 3 columns]

# %%
# see if there are Neighbourhoods that are Not assigned
uniques = df['Neighbourhood'].unique()
'Not assigned' in uniques
# Out:
# True

# %%
rows, cols = df.shape

# %%
rows
# Out:
# 210

# %%
cols
# Out:
# 3

# %%
# set Not assigned Neighbourhoods to the corresponding Borough 
for i in range(rows) :
  if df.iloc[i, 2] == 'Not assigned':
    df.iloc[i, 2] = df.iloc[i, 1]

# %%
# check again
uniques = df['Neighbourhood'].unique()
'Not assigned' in uniques
# Out:
# False

# %%
# check shape as asked in the assignment
df.shape
# Out:
# (210, 3)

# %% [markdown]
# # part 2

# %%
# define the new columns
df['latitude'] = 0.0
df['longitude'] = 0.0
df
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#     Postcode           Borough             Neighbourhood  latitude  longitude
# 0        M3A        North York                 Parkwoods       0.0        0.0
# ...

# %%
rows, cols = df.shape

# %%
rows
# Out:
# 210

# %%
cols
# Out:
# 5

# %%
# import csv file of the locations as geocoder didn't work
latlngs=pd.read_csv('http://cocl.us/Geospatial_data')
latlngs
# Out:
#     Postal Code   Latitude  Longitude
# 0           M1B  43.806686 -79.194353
# 1           M1C  43.784535 -79.160497
# 2           M1E  43.763573 -79.188711
# 3           M1G  43.770992 -79.216917
# 4           M1H  43.773136 -79.239476
# ..          ...        ...        ...
# 98          M9N  43.706876 -79.518188
# 99          M9P  43.696319 -79.532242
# 100         M9R  43.688905 -79.554724
# 101         M9V  43.739416 -79.588437
# 102         M9W  43.706748 -79.594054
#
# [103 rows x 3 columns]

# %%
# reindex to use the loc method on the dataframe
latlngs.set_index('Postal Code', inplace=True)

# %%
latlngs
# Out:
#               Latitude  Longitude
# Postal Code
# M1B          43.806686 -79.194353
# M1C          43.784535 -79.160497
# M1E          43.763573 -79.188711
# M1G          43.770992 -79.216917
# M1H          43.773136 -79.239476
# ...                ...        ...
# M9N          43.706876 -79.518188
# M9P          43.696319 -79.532242
# M9R          43.688905 -79.554724
# M9V          43.739416 -79.588437
# M9W          43.706748 -79.594054
#
# [103 rows x 2 columns]

# %%
# for each neighbourhood, find the lat and lng of it's post code by locating them in latlngs and fill the corresponding cells ofin df
for i in range(rows) :
  postal_code = df.iloc[i, 0]
  df.loc[i, 'latitude'] = latlngs.loc[postal_code, 'Latitude']
  df.loc[i, 'longitude'] = latlngs.loc[postal_code, 'Longitude']
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexing.py:494: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s

# %%
# the new complete dataframe 
df
# Out:
#     Postcode           Borough             Neighbourhood   latitude  longitude
# 0        M3A        North York                 Parkwoods  43.753259 -79.329656
# 1        M4A        North York          Victoria Village  43.725882 -79.315572
# 2        M5A  Downtown Toronto              Harbourfront  43.654260 -79.360636
# 3        M6A        North York          Lawrence Heights  43.718518 -79.464763
# 4        M6A        North York            Lawrence Manor  43.718518 -79.464763
# ..       ...               ...                       ...        ...        ...
# 205      M8Z         Etobicoke  Kingsway Park South West  43.628841 -79.520999
# 206      M8Z         Etobicoke                 Mimico NW  43.628841 -79.520999
# 207      M8Z         Etobicoke        The Queensway West  43.628841 -79.520999
# 208      M8Z         Etobicoke     Royal York South West  43.628841 -79.520999
# 209      M8Z         Etobicoke            South of Bloor  43.628841 -79.520999
#
# [210 rows x 5 columns]

# %% [markdown]
# # part 3

# %%
# import additional libraries
import folium
import json
import requests
from pandas.io.json import json_normalize
import matplotlib.cm as cm
import matplotlib.colors as colors
from sklearn.cluster import KMeans

# %%
# lets work with this dataframe with a better name
neighborhoods=df

# %%
# lets have some insight about Toronto
print('Toronto has {} boroughs and {} neighborhoods.'.format(
        len(neighborhoods['Borough'].unique()),
        neighborhoods.shape[0]
    )
)
# Out:
# Toronto has 11 boroughs and 210 neighborhoods.

# %%
from geopy.geocoders import Nominatim

# %%
# lets retreive location of Toronto
address = 'Toronto, Ontario'

geolocator = Nominatim(user_agent="ny_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude

# %%
latitude
# Out:
# 43.653963

# %%
longitude
# Out:
# -79.387207

# %%
# create map of Toronto using latitude and longitude values
map_toronto = folium.Map(location=[latitude, longitude], zoom_start=10)

# add markers to map
for lat, lng, borough, neighborhood in zip(neighborhoods['latitude'], neighborhoods['longitude'], neighborhoods['Borough'], neighborhoods['Neighbourhood']):
    label = '{}, {}'.format(neighborhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_toronto)  
    
map_toronto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
CLIENT_ID = 'QL0FTK300RYC0NTMNHTH4NUMMAJXC4FRY0FAYIRTV5Y3BWUI' #  Foursquare ID
CLIENT_SECRET = '0TVXWR120LOEHWJLQCMCASWQI33CA01C3AXR4OITKPG4PZIC' #  Foursquare Secret
VERSION = '20180605' # Foursquare API version

print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: QL0FTK300RYC0NTMNHTH4NUMMAJXC4FRY0FAYIRTV5Y3BWUI
# CLIENT_SECRET:0TVXWR120LOEHWJLQCMCASWQI33CA01C3AXR4OITKPG4PZIC

# %%
LIMIT=100
radius=500

# %%
def getNearbyVenues(names, latitudes, longitudes, radius=500):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %%
# lets find the venues in Toronto
venues = getNearbyVenues(names=neighborhoods['Neighbourhood'],
                                   latitudes=neighborhoods['latitude'],
                                   longitudes=neighborhoods['longitude']
                                  )
# Out:
# Parkwoods
# Victoria Village
# Harbourfront
# Lawrence Heights
# Lawrence Manor
# Queen's Park
# Queen's Park
# Rouge
# Malvern
# Don Mills North
# Woodbine Gardens
# Parkview Hill
# Ryerson
# Garden District
# Glencairn
# Cloverdale
# Islington
# Martin Grove
# Princess Gardens
# West Deane Park
# Highland Creek
# Rouge Hill
# Port Union
# Flemingdon Park
# Don Mills South
# Woodbine Heights
# St. James Town
# Humewood-Cedarvale
# Bloordale Gardens
# Eringate
# Markland Wood
# Old Burnhamthorpe
# Guildwood
# Morningside
# West Hill
# The Beaches
# Berczy Park
# Caledonia-Fairbanks
# Woburn
# Leaside
# Central Bay Street
# Christie
# Cedarbrae
# Hillcrest Village
# Bathurst Manor
# Downsview North
# Wilson Heights
# Thorncliffe Park
# Adelaide
# King
# Richmond
# Dovercourt Village
# Dufferin
# Scarborough Village
# Fairview
# Henry Farm
# Oriole
# Northwood Park
# York University
# East Toronto
# Harbourfront East
# Toronto Islands
# Union Station
# Little Portugal
# Trinity
# ...

# %%
# lets see how many venues we have and get a look at first rows
print(venues.shape)
venues.head()
# Out:
# (4379, 7)
#        Neighborhood  Neighborhood Latitude  ...  Venue Longitude     Venue Category
# 0         Parkwoods              43.753259  ...       -79.332140               Park
# 1         Parkwoods              43.753259  ...       -79.333477    Fireworks Store
# 2         Parkwoods              43.753259  ...       -79.333114  Food & Drink Shop
# 3  Victoria Village              43.725882  ...       -79.315635       Hockey Arena
# 4  Victoria Village              43.725882  ...       -79.313103        Coffee Shop
#
# [5 rows x 7 columns]

# %%
# lets see how many categories of venues we have
len(venues['Venue Category'].unique())
# Out:
# 270

# %%
# one hot encoding
toronto_onehot = pd.get_dummies(venues[['Venue Category']], prefix="", prefix_sep="")
len(toronto_onehot.columns)
# Out:
# 270

# %%
# it seems we have a columns with a name 'Neighborhood', this may lead to problems later as we will define a column with the same name
'Neighborhood' in toronto_onehot.columns
# Out:
# True

# %%
# so lets change its name slightly
toronto_onehot.rename(columns={"Neighborhood": "neighborhood"}, inplace=True)

# %%
# move neighborhood column to the first column
toronto_onehot = pd.concat([venues['Neighborhood'], toronto_onehot], axis=1)

toronto_onehot.head()
# Out:
#        Neighborhood  Accessories Store  ...  Women's Store  Yoga Studio
# 0         Parkwoods                  0  ...              0            0
# 1         Parkwoods                  0  ...              0            0
# 2         Parkwoods                  0  ...              0            0
# 3  Victoria Village                  0  ...              0            0
# 4  Victoria Village                  0  ...              0            0
#
# [5 rows x 271 columns]

# %%
toronto_onehot.shape
# Out:
# (4379, 271)

# %%
#let's group rows by neighborhood and by taking the mean of the frequency of occurrence of each category
toronto_grouped = toronto_onehot.groupby('Neighborhood').mean().reset_index()
toronto_grouped
# Out:
#          Neighborhood  Accessories Store  ...  Women's Store  Yoga Studio
# 0            Adelaide                0.0  ...            0.0          0.0
# 1           Agincourt                0.0  ...            0.0          0.0
# 2     Agincourt North                0.0  ...            0.0          0.0
# 3      Albion Gardens                0.0  ...            0.0          0.0
# 4           Alderwood                0.0  ...            0.0          0.0
# ..                ...                ...  ...            ...          ...
# 199  Woodbine Heights                0.0  ...            0.0          0.0
# 200        York Mills                0.0  ...            0.0          0.0
# 201   York Mills West                0.0  ...            0.0          0.0
# 202   York University                0.0  ...            0.0          0.0
# 203         Yorkville                0.0  ...            0.0          0.0
#
# [204 rows x 271 columns]

# %%
toronto_grouped.shape
# Out:
# (204, 271)

# %%
# Let's print each neighborhood along with the top 5 most common venues
num_top_venues = 5

for hood in toronto_grouped['Neighborhood']:
    print("----"+hood+"----")
    temp = toronto_grouped[toronto_grouped['Neighborhood'] == hood].T.reset_index()
    temp.columns = ['venue','freq']
    temp = temp.iloc[1:]
    temp['freq'] = temp['freq'].astype(float)
    temp = temp.round({'freq': 2})
    print(temp.sort_values('freq', ascending=False).reset_index(drop=True).head(num_top_venues))
    print('\n')
# Out:
# ----Adelaide----
#              venue  freq
# 0      Coffee Shop  0.07
# 1             Café  0.05
# 2       Steakhouse  0.04
# 3              Bar  0.04
# 4  Thai Restaurant  0.03
#
#
# ----Agincourt----
#                        venue  freq
# 0  Latin American Restaurant  0.25
# 1                     Lounge  0.25
# 2             Breakfast Spot  0.25
# 3               Skating Rink  0.25
# 4         Miscellaneous Shop  0.00
#
#
# ----Agincourt North----
#                 venue  freq
# 0          Playground  0.33
# 1         Coffee Shop  0.33
# 2                Park  0.33
# 3  Miscellaneous Shop  0.00
# 4       Movie Theater  0.00
#
#
# ----Albion Gardens----
#                   venue  freq
# 0           Pizza Place  0.11
# 1        Discount Store  0.11
# 2  Fast Food Restaurant  0.11
# 3            Beer Store  0.11
# 4   Fried Chicken Joint  0.11
#
#
# ----Alderwood----
#             venue  freq
# 0     Pizza Place  0.25
# 1        Pharmacy  0.12
# 2             Gym  0.12
# ...

# %%
# let's write a function to sort the venues in descending order.
def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]

# %%
# let's create the new dataframe and display the top 10 venues for each neighborhood
num_top_venues = 10

indicators = ['st', 'nd', 'rd']

# create columns according to number of top venues
columns = ['Neighborhood']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))

# create a new dataframe
neighborhoods_venues_sorted = pd.DataFrame(columns=columns)
neighborhoods_venues_sorted['Neighborhood'] = toronto_grouped['Neighborhood']

for ind in np.arange(toronto_grouped.shape[0]):
    neighborhoods_venues_sorted.iloc[ind, 1:] = return_most_common_venues(toronto_grouped.iloc[ind, :], num_top_venues)

neighborhoods_venues_sorted.head()
# Out:
#       Neighborhood  ... 10th Most Common Venue
# 0         Adelaide  ...             Restaurant
# 1        Agincourt  ...      Electronics Store
# 2  Agincourt North  ...             Donut Shop
# 3   Albion Gardens  ...          Deli / Bodega
# 4        Alderwood  ...     Falafel Restaurant
#
# [5 rows x 11 columns]

# %% [markdown]
# ### KMeans Clustering

# %%
# Run k-means to cluster the neighborhood into 5 clusters.

# set number of clusters
kclusters = 5

toronto_grouped_clustering = toronto_grouped.drop('Neighborhood', 1)

# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(toronto_grouped_clustering)

# check cluster labels generated for each row in the dataframe
kmeans.labels_[0:10]
# Out:
# array([1, 1, 0, 2, 1, 1, 1, 1, 2, 1], dtype=int32)

# %%
# Let's create a new dataframe that includes the cluster as well as the top 10 venues for each neighborhood.

# add clustering labels
neighborhoods_venues_sorted.insert(0, 'Cluster Labels', kmeans.labels_)

toronto_merged = neighborhoods

# merge toronto_grouped with toronto_data to add latitude/longitude for each neighborhood
toronto_merged = toronto_merged.join(neighborhoods_venues_sorted.set_index('Neighborhood'), on='Neighbourhood')

toronto_merged.replace(np.nan, 0, inplace=True)
toronto_merged['Cluster Labels'] = toronto_merged['Cluster Labels'].astype(int)

toronto_merged.head() # check the last columns!
# Out:
#   Postcode           Borough  ... 9th Most Common Venue       10th Most Common Venue
# 0      M3A        North York  ...             Drugstore  Eastern European Restaurant
# 1      M4A        North York  ...     Electronics Store                 Dessert Shop
# 2      M5A  Downtown Toronto  ...                  Bank            French Restaurant
# 3      M6A        North York  ...         Women's Store        Vietnamese Restaurant
# 4      M6A        North York  ...         Women's Store        Vietnamese Restaurant
#
# [5 rows x 16 columns]

# %%
# Finally, let's visualize the resulting clusters

# create map
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=11)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(toronto_merged['latitude'], toronto_merged['longitude'], toronto_merged['Neighbourhood'], toronto_merged['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Now, you can examine each cluster and determine the discriminating venue categories that distinguish each cluster. Based on the defining categories, you can then assign a name to each cluster. I will leave this exercise to you.

# %%
# cluster 1

toronto_merged.loc[toronto_merged['Cluster Labels'] == 0, toronto_merged.columns[[1] + list(range(5, toronto_merged.shape[1]))]]
# Out:
#               Borough  ...       10th Most Common Venue
# 0          North York  ...  Eastern European Restaurant
# 37               York  ...            Electronics Store
# 59          East York  ...                    Drugstore
# 69         North York  ...                   Donut Shop
# 70         North York  ...                   Donut Shop
# 81         North York  ...  Eastern European Restaurant
# 82         North York  ...  Eastern European Restaurant
# 95         North York  ...                            0
# 96         North York  ...                            0
# 111   Central Toronto  ...          Dumpling Restaurant
# 115              York  ...  Eastern European Restaurant
# 119        North York  ...                    Drugstore
# 121   Central Toronto  ...                    Drugstore
# 122   Central Toronto  ...                    Drugstore
# 149   Central Toronto  ...             Doner Restaurant
# 150   Central Toronto  ...             Doner Restaurant
# ...

# %%
# cluster 2

toronto_merged.loc[toronto_merged['Cluster Labels'] == 1, toronto_merged.columns[[1] + list(range(5, toronto_merged.shape[1]))]]
# Out:
#               Borough  ...  10th Most Common Venue
# 1          North York  ...            Dessert Shop
# 2    Downtown Toronto  ...       French Restaurant
# 3          North York  ...   Vietnamese Restaurant
# 4          North York  ...   Vietnamese Restaurant
# 5        Queen's Park  ...           Burrito Place
# ..                ...  ...                     ...
# 205         Etobicoke  ...                     Gym
# 206         Etobicoke  ...                     Gym
# 207         Etobicoke  ...                     Gym
# 208         Etobicoke  ...                     Gym
# 209         Etobicoke  ...                     Gym
#
# [150 rows x 12 columns]

# %%
# cluster 3

toronto_merged.loc[toronto_merged['Cluster Labels'] == 2, toronto_merged.columns[[1] + list(range(5, toronto_merged.shape[1]))]]
# Out:
#          Borough  ...  10th Most Common Venue
# 7    Scarborough  ...     Dumpling Restaurant
# 8    Scarborough  ...     Dumpling Restaurant
# 10     East York  ...                Pharmacy
# 11     East York  ...                Pharmacy
# 43    North York  ...              Donut Shop
# 101         York  ...              Donut Shop
# 102         York  ...              Donut Shop
# 103         York  ...              Donut Shop
# 104         York  ...              Donut Shop
# 173    Etobicoke  ...           Deli / Bodega
# 174    Etobicoke  ...           Deli / Bodega
# 175    Etobicoke  ...           Deli / Bodega
# 176    Etobicoke  ...           Deli / Bodega
# 177    Etobicoke  ...           Deli / Bodega
# 178    Etobicoke  ...           Deli / Bodega
# 179    Etobicoke  ...           Deli / Bodega
# 180    Etobicoke  ...           Deli / Bodega
# 181  Scarborough  ...   General Entertainment
#
# [18 rows x 12 columns]

# %%
# cluster 4

toronto_merged.loc[toronto_merged['Cluster Labels'] == 3, toronto_merged.columns[[1] + list(range(5, toronto_merged.shape[1]))]]
# Out:
#       Borough  Cluster Labels  ... 9th Most Common Venue 10th Most Common Venue
# 15  Etobicoke               3  ...   Dumpling Restaurant      Electronics Store
# 16  Etobicoke               3  ...   Dumpling Restaurant      Electronics Store
# 17  Etobicoke               3  ...   Dumpling Restaurant      Electronics Store
# 18  Etobicoke               3  ...   Dumpling Restaurant      Electronics Store
# 19  Etobicoke               3  ...   Dumpling Restaurant      Electronics Store
#
# [5 rows x 12 columns]

# %%
# cluster 5

toronto_merged.loc[toronto_merged['Cluster Labels'] == 4, toronto_merged.columns[[1] + list(range(5, toronto_merged.shape[1]))]]
# Out:
#              Borough  ...  10th Most Common Venue
# 97        North York  ...             Yoga Studio
# 105       North York  ...                   Field
# 106       North York  ...                   Field
# 112  Central Toronto  ...             Yoga Studio
# 197        Etobicoke  ...             Yoga Studio
# 198        Etobicoke  ...             Yoga Studio
# 199        Etobicoke  ...             Yoga Studio
# 200        Etobicoke  ...             Yoga Studio
# 201        Etobicoke  ...             Yoga Studio
# 202        Etobicoke  ...             Yoga Studio
# 203        Etobicoke  ...             Yoga Studio
# 204        Etobicoke  ...             Yoga Studio
#
# [12 rows x 12 columns]
